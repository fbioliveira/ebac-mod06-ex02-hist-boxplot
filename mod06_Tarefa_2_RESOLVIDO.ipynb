# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

data = pd.read_csv('SINASC_RO_2019.csv')
data['PESO']
# Out:
# 0        3685
# 1        3055
# 2        3460
# 3        2982
# 4        3310
#          ...
# 27023    2110
# 27024    3310
# 27025    3065
# 27026    2352
# 27027    4240
# Name: PESO, Length: 27028, dtype: int64

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sns.boxplot(y='IDADEMAE', data = data)
# Out:
# <Axes: ylabel='IDADEMAE'>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(y='PESO', data = data)
# Out:
# <Axes: ylabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.displot(
    data = data
    ,x = 'IDADEMAE'
    ,bins = 20
    ,element = 'step'
    ,kde = True
)

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.displot(
    data = data
    ,x = 'PESO'
    ,bins = 20
    ,element = 'step'
    ,kde = True
)
